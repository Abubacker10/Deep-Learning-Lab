# %% [markdown]
# <a href="https://colab.research.google.com/github/Abubacker10/Deep-Learning-Lab/blob/main/Mathematical_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv

import numpy as np

import matplotlib.pyplot as plt

img = cv.imread('/content/j.jpeg',0)

kernel=np.ones((5,5), np.uint8)

erosion = cv.erode(img, kernel, iterations = 1)

plt.imshow(erosion, cmap='gray')
plt.show()

dilation = cv.dilate(img, kernel, iterations = 1)

plt.imshow(dilation, cmap='gray')

plt.show()

opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.imshow(opening, cmap='gray')

plt.show()

closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
plt.imshow(closing, cmap='gray')

plt.show()

gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
plt.imshow(gradient, cmap='gray')

plt.show()

tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
plt.imshow(tophat, cmap='gray')

plt.show()
